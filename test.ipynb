# %%
# %load_ext autoreload
# %autoreload 2

from pyfixest.utils.dgps import gelbach_data
import numpy as np
import pyfixest as pf

# Generate test data using gelbach_data
data = gelbach_data(nobs=500)
data["w"] = np.random.rand(500)
fit = pf.feols("y ~ x1 + x21 + x22 + x23", data=data)
gb = fit.decompose(decomp_var = "x1", x1_vars = ["x21"],reps = 10, nthreads = 1)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 231.34it/s]

# %%
gb.tidy()
# Out:
#                     coefficients  ci_lower   ci_upper  \
# x22                     0.061930 -0.414556   0.467074
# x23                     0.308483  0.026815   0.567724
# explained_effect        0.370412 -0.384258   1.034798
# unexplained_effect      1.041753  0.954127   1.107870
# direct_effect           1.412165  0.651301   2.022201
# full_effect             1.041753  0.954127   1.107870
# x22                     0.043855 -0.736488   0.230730
# x23                     0.218446  0.012120   0.280648
# explained_effect        0.262301 -0.719049   0.511378
# unexplained_effect      0.737699  0.488622   1.719049
# direct_effect           1.000000  1.000000   1.000000
# full_effect             0.737699  0.488622   1.719049
# x22                     0.167192 -5.753520   0.852267
# x23                     0.832808  0.147733   6.753520
# explained_effect        1.000000  1.000000   1.000000
# unexplained_effect      2.812414 -1.401041  36.248907
# direct_effect           3.812414 -0.401041  37.248907
# full_effect             2.812414 -1.401041  36.248907
#
#                                         stats
# x22                            Levels (units)
# x23                            Levels (units)
# explained_effect               Levels (units)
# unexplained_effect             Levels (units)
# direct_effect                  Levels (units)
# full_effect                    Levels (units)
# x22                      Share of Full Effect
# x23                      Share of Full Effect
# explained_effect         Share of Full Effect
# unexplained_effect       Share of Full Effect
# direct_effect            Share of Full Effect
# full_effect              Share of Full Effect
# x22                 Share of Explained Effect
# x23                 Share of Explained Effect
# explained_effect    Share of Explained Effect
# unexplained_effect  Share of Explained Effect
# direct_effect       Share of Explained Effect
# full_effect         Share of Explained Effect

# %%
gb.summary()
# Out:
# ###
#
# Gelbach Decomposition Results
# Decomposition variable: x1
# Control variables: x21
#
# |                                               | direct_effect   | full_effect    | explained_effect   |
# |:----------------------------------------------|:----------------|:---------------|:-------------------|
# | ('Levels (units)', 'x1')                      | 1.412           | 1.042          | 0.370              |
# | ('Levels (units)', '')                        | [0.651, 2.022]  | [0.954, 1.108] | [-0.384, 1.035]    |
# | ('Levels (units)', np.str_('x22'))            | -               | -              | 0.062              |
# | ('Levels (units)', '')                        | -               | -              | [-0.415, 0.467]    |
# | ('Levels (units)', np.str_('x23'))            | -               | -              | 0.308              |
# | ('Levels (units)', '')                        | -               | -              | [0.027, 0.568]     |
# | ('Share of Full Effect', 'x1')                | 1.000           | 0.738          | 0.262              |
# | ('Share of Full Effect', '')                  | -               | [0.489, 1.719] | [-0.719, 0.511]    |
# | ('Share of Full Effect', np.str_('x22'))      | -               | -              | 0.044              |
# | ('Share of Full Effect', '')                  | -               | -              | [-0.736, 0.231]    |
# | ('Share of Full Effect', np.str_('x23'))      | -               | -              | 0.218              |
# | ('Share of Full Effect', '')                  | -               | -              | [0.012, 0.281]     |
# | ('Share of Explained Effect', 'x1')           | -               | -              | 1.000              |
# | ('Share of Explained Effect', np.str_('x22')) | -               | -              | 0.167              |
# | ('Share of Explained Effect', '')             | -               | -              | [-5.754, 0.852]    |
# | ('Share of Explained Effect', np.str_('x23')) | -               | -              | 0.833              |
# | ('Share of Explained Effect', '')             | -               | -              | [0.148, 6.754]     |
# ---

# %%
gb.etable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 gb.etable()
#
# File c:\Users\alexa\Documents\pyfixest\pyfixest\estimation\decomposition.py:678, in GelbachDecomposition.etable(self, stats, caption, model_heads, rgroup_sep, add_notes, **kwargs)
#     670     default_model_notes.append(f"Panel {panel}: Share of Explained Effect: Levels normalized by coefficient of the long regression.")
#     672 default_model_heads = [
#     673     "Initial Difference",
#     674     "Adjusted Difference",
#     675     "Explained Difference",
#     676 ]
# --> 678 res_sub.columns = model_heads if model_heads is not None else default_model_heads
#     681 notes = f"""
#     682     Decomposition variable: {self.decomp_var}.
#     683 """
#     685 if self.x1_vars is not None:
#
# File c:\Users\alexa\Documents\pyfixest\.pixi\envs\dev\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\alexa\Documents\pyfixest\.pixi\envs\dev\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
#     815 self._clear_item_cache()
#
# File c:\Users\alexa\Documents\pyfixest\.pixi\envs\dev\Lib\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File c:\Users\alexa\Documents\pyfixest\.pixi\envs\dev\Lib\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 3 elements
