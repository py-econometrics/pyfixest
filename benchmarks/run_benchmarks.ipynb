# %% [markdown]
# # PyFixest Benchmarks

# %%
# %load_ext autoreload
# %autoreload 2

import time

import pandas as pd
from linearmodels.iv import AbsorbingLS
from tqdm import tqdm  # note: tqdm is not a dependency of pyfixest

from pyfixest.estimation import feols, fepois


def run_standard_benchmark(model, fixed_effect):
    "Run the standard benchmark for the fixed effect models."
    assert model in ["feols", "fepois", "absorbingls"]
    assert fixed_effect in ["dum_1", "dum_1+dum_2", "dum_1+dum_2+dum_3"]

    # one fixed effect
    res = []

    fml_base = "ln_y ~ X1" if model == "feols" else "y ~ X1"
    fml = f"{fml_base} | {fixed_effect}"

    # warmup
    df = pd.read_stata("./data/_STATA/base_s2_r1.dta")
    feols(fml, data=df)

    for size in tqdm(range(1, 6)):
        if size == 5:
            if model == "fepois":
                pass
            else:
                df = pd.read_csv("./data/data/base_10M.csv")

        for rep in range(1, 11):
            if size < 5:
                df = pd.read_stata(f"./data/_STATA/base_s{size}_r{rep}.dta")

            tic = time.time()
            if model == "feols":
                feols(fml, data=df)
            elif model == "absorbingls":
                df = df.astype({f"dum_{i}": "category" for i in range(1, 4)})
                df_exog = df[["X1"]]

                absorb_columns = fixed_effect.split("+")
                df_absorb = df[absorb_columns]
                df_endog = df["ln_y"]
                # I don't think the approach gives analogous standard errors
                AbsorbingLS(df_endog, df_exog, absorb=df_absorb).fit(
                    cov_type="clustered"
                )
            else:
                fepois(fml, data=df)
            toc = time.time()

            res.append(
                pd.Series(
                    {
                        "method": model,
                        "n_obs": df.shape[0],
                        "G": len(fixed_effect.split("+")),
                        "rep": rep,
                        "time": toc - tic,
                    }
                )
            )

    return pd.concat(res, axis=1).T


def run_all_benchmarks():
    "Run all the benchmarks."
    res = pd.DataFrame()
    for model in ["feols", "fepois", "absorbingls"]:
        for fixef in ["dum_1", "dum_1+dum_2", "dum_1+dum_2+dum_3"]:
            res = pd.concat([res, run_standard_benchmark(model, fixef)], axis=0)

    res.to_csv("./results_py.csv")
# Out:
#             <div id="4ln53B"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("4ln53B").appendChild(div);
#                     };
#                     var e = document.getElementById("4ln53B");
#                     e.appendChild(script);
#                 })()
#             </script>
#             <div id="IBBLxn"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("IBBLxn").appendChild(div);
#                     };
#                     var e = document.getElementById("IBBLxn");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
run_all_benchmarks()
# Out:
# 100%|██████████| 5/5 [00:23<00:00,  4.76s/it]
# 100%|██████████| 5/5 [00:28<00:00,  5.67s/it]
# 100%|██████████| 5/5 [00:30<00:00,  6.18s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 15 observations removed because of separation.
#   warnings.warn(
#  20%|██        | 1/5 [00:01<00:05,  1.34s/it]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 19 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 15 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 14 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 50 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 28 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 30 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 59 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 27 observations removed because of separation.
#   warnings.warn(
#  40%|████      | 2/5 [00:02<00:02,  1.02it/s]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 344 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 367 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 126 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 212 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 702 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 155 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 70 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 457 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 197 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 196 observations removed because of separation.
#   warnings.warn(
#  60%|██████    | 3/5 [00:03<00:02,  1.26s/it]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1645 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 3018 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 3068 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1682 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1768 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1302 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 2236 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 2304 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1686 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
#  80%|████████  | 4/5 [00:14<00:05,  5.06s/it]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# 100%|██████████| 5/5 [00:25<00:00,  5.04s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 15 observations removed because of separation.
#   warnings.warn(
#  20%|██        | 1/5 [00:01<00:05,  1.35s/it]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 19 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 15 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 14 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 50 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 28 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 30 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 59 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 27 observations removed because of separation.
#   warnings.warn(
#  40%|████      | 2/5 [00:02<00:03,  1.11s/it]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 344 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 367 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 126 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 212 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 702 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 155 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 70 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 457 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 197 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 196 observations removed because of separation.
#   warnings.warn(
#  60%|██████    | 3/5 [00:04<00:03,  1.82s/it]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1645 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 3018 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 3068 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1682 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1768 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1302 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 2236 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 2304 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1686 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
#  80%|████████  | 4/5 [00:33<00:12, 12.33s/it]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# 100%|██████████| 5/5 [01:06<00:00, 13.37s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 15 observations removed because of separation.
#   warnings.warn(
#  20%|██        | 1/5 [00:00<00:02,  1.44it/s]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 19 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 15 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 14 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 50 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 28 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 30 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 59 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 27 observations removed because of separation.
#   warnings.warn(
#  40%|████      | 2/5 [00:01<00:02,  1.09it/s]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 344 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 367 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 126 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 212 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 702 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 155 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 70 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 457 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 197 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 196 observations removed because of separation.
#   warnings.warn(
#  60%|██████    | 3/5 [00:05<00:04,  2.15s/it]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1645 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 3018 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 3068 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1682 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1768 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1302 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 2236 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 2304 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1686 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
#  80%|████████  | 4/5 [00:48<00:18, 18.50s/it]/Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# /Users/marc/Documents/pyfixest/pyfixest/estimation/fepois_.py:139: UserWarning: 1631 observations removed because of separation.
#   warnings.warn(
# 100%|██████████| 5/5 [01:43<00:00, 20.69s/it]
# 100%|██████████| 5/5 [37:23<00:00, 448.78s/it]
# 100%|██████████| 5/5 [1:26:09<00:00, 1033.99s/it]
# 100%|██████████| 5/5 [1:44:48<00:00, 1257.66s/it]

# %%
a = run_standard_benchmark("feols", "dum_1")
a
# Out:
# 100%|██████████| 5/5 [16:53<00:00, 202.62s/it]
#    method     n_obs  G rep        time
# 0   feols      1000  1   1    0.056183
# 1   feols      1000  1   2     0.05277
# 2   feols      1000  1   3    0.052286
# 3   feols      1000  1   4    0.052665
# 4   feols      1000  1   5    0.052282
# 5   feols      1000  1   6    0.052521
# 6   feols      1000  1   7    0.052853
# 7   feols      1000  1   8    0.053038
# 8   feols      1000  1   9    0.053121
# 9   feols      1000  1  10    0.052397
# 10  feols     10000  1   1    0.054689
# 11  feols     10000  1   2    0.053319
# 12  feols     10000  1   3    0.054951
# 13  feols     10000  1   4    0.053898
# 14  feols     10000  1   5     0.05422
# 15  feols     10000  1   6    0.055358
# 16  feols     10000  1   7    0.054344
# 17  feols     10000  1   8      0.0599
# 18  feols     10000  1   9    0.056684
# 19  feols     10000  1  10    0.054084
# 20  feols    100000  1   1    0.064738
# 21  feols    100000  1   2    0.062995
# 22  feols    100000  1   3    0.064231
# 23  feols    100000  1   4    0.063408
# 24  feols    100000  1   5    0.063151
# 25  feols    100000  1   6    0.065336
# 26  feols    100000  1   7    0.064017
# 27  feols    100000  1   8    0.063007
# 28  feols    100000  1   9    0.065574
# 29  feols    100000  1  10     0.06459
# 30  feols   1000000  1   1    0.180321
# 31  feols   1000000  1   2     0.18074
# 32  feols   1000000  1   3    0.178868
# 33  feols   1000000  1   4    0.175977
# 34  feols   1000000  1   5    0.175205
# 35  feols   1000000  1   6    0.178113
# 36  feols   1000000  1   7    0.175998
# 37  feols   1000000  1   8    0.178389
# 38  feols   1000000  1   9     0.17657
# 39  feols   1000000  1  10    0.172102
# 40  feols  10000000  1   1  992.064057
# 41  feols  10000000  1   2    1.935793
# 42  feols  10000000  1   3     1.74646
# 43  feols  10000000  1   4    1.726809
# 44  feols  10000000  1   5    1.662941
# 45  feols  10000000  1   6     1.64592
# 46  feols  10000000  1   7    1.652289
# 47  feols  10000000  1   8    1.667719
# 48  feols  10000000  1   9    1.649755
# 49  feols  10000000  1  10    1.645669

# %%
a.T
# Out:
#               0        1         2         3         4         5         6   \
# method     feols    feols     feols     feols     feols     feols     feols
# n_obs       1000     1000      1000      1000      1000      1000      1000
# G              1        1         1         1         1         1         1
# rep            1        2         3         4         5         6         7
# time    0.056183  0.05277  0.052286  0.052665  0.052282  0.052521  0.052853
#
#               7         8         9   ...          40        41        42  \
# method     feols     feols     feols  ...       feols     feols     feols
# n_obs       1000      1000      1000  ...    10000000  10000000  10000000
# G              1         1         1  ...           1         1         1
# rep            8         9        10  ...           1         2         3
# time    0.053038  0.053121  0.052397  ...  992.064057  1.935793   1.74646
#
#               43        44        45        46        47        48        49
# method     feols     feols     feols     feols     feols     feols     feols
# n_obs   10000000  10000000  10000000  10000000  10000000  10000000  10000000
# G              1         1         1         1         1         1         1
# rep            4         5         6         7         8         9        10
# time    1.726809  1.662941   1.64592  1.652289  1.667719  1.649755  1.645669
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Visualisation

# %%
res_all = pd.concat(
    [
        pd.read_csv("./results_py.csv"),
        pd.read_csv("./results_all.txt"),
    ]
)
